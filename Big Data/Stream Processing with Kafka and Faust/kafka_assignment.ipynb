# %% [markdown]
# # Assignment 5 - Kafka
# #### Stefanela Stevanović

# %% [markdown]
# ## Problem description

# %% [markdown]
# In this assignment, we use Apache Kafka to process meteorological data from three US cities: Austin, Bronte, and Spokane. The dataset contains a variety of meteorological measurements collected every 5 minutes. However, for this assignment, we are specifically interested in analyzing the air temperature data. The goal of this assignment is to simulate real-time data streaming and perform the following tasks:
#
# * Compute the hourly temperature (hourly mean) for each station.
# * Stream temperature data from the three stations and report the station with the highest hourly temperature using subhourly data.
# * Implement an algorithm to detect outliers in the temperature data stream.
#
#
# To achieve these goals, we will set up Kafka producers and consumers, and implement data processing using Faust.

# %% [markdown]
# ## Getting Started

# %% [markdown]
# Firstly, we import all necessary libraries to do this project. We need 'confluent_kafka' for writting Kafka Producer and Consumer and 'threading' to be able to run them in parallel.

# %%
# Importing libraries

import confluent_kafka as kafka, socket
from confluent_kafka import KafkaError
import os, socket
import pandas as pd
import json
import time
from datetime import datetime
import threading
from queue import Queue
import logging

logging.basicConfig(level=logging.INFO)

# %% [markdown]
# ## Defining Kafka Producer

# %% [markdown]
# First, we define the producer configuration and specify the paths to the data files. We then implement the 'run_producer' function, which will sequentially send data to the Kafka InputData topic from three text files, each corresponding to a different city: Austin, Bronte, and Spokane.

# %%
# Defining producer configuration
producer = kafka.Producer({'bootstrap.servers': "localhost:29092",
                  'client.id': socket.gethostname()})

# Defining path to the data
data_path = './data/'
filenames = ["Austin_data.txt", "Bronte_data.txt", "Spokane_data.txt"]

columns = [
    "WBANNO", "UTC_DATE", "UTC_TIME", "LST_DATE", "LST_TIME", "CRX_VN",
    "LONGITUDE", "LATITUDE", "AIR_TEMPERATURE", "PRECIPITATION",
    "SOLAR_RADIATION", "SR_FLAG", "SURFACE_TEMPERATURE", "ST_TYPE",
    "ST_FLAG", "RELATIVE_HUMIDITY", "RH_FLAG", "SOIL_MOISTURE_5",
    "SOIL_TEMPERATURE_5", "WETNESS", "WET_FLAG", "WIND_1_5", "WIND_FLAG"
]

# Function for printing error message
def error_report(err, msg):
    if err is not None:
        logging.error(f"Message delivery failed: {err}")

# Function for running the producer
def run_producer():
    for filename in filenames:
        file_path = os.path.join(data_path, filename)
        if os.path.isfile(file_path):
            df = pd.read_csv(file_path, delimiter=r'\s+', names=columns)
            for _, row in df.iterrows():
                data = row.to_dict()
                data['source_file'] = filename  
                producer.produce('InputData', key=None, value=json.dumps(data), callback=error_report)
                producer.poll(0)
            
    producer.flush()
    logging.info("All messages delivered to InputData Topic!")

# %% [markdown]
# ## Stream Processing with Faust

# %% [markdown]
# We will use Faust to process data from the 'InputData' topic, which is populated by our producer. The code for this processing is contained in a separate Python script, 'faust_app.'py', as it will be run from the terminal in parallel with the Producer and Consumer. Below, we will highlight some important sections from that script.
#
# Additionally, we have created two more Kafka topics: 'Output' and 'Outliers'. These topics are specified in our 'faust_app.py' script and will be used to store the processed data from the Faust application.

# %% [markdown]
# ```python
#
# # Defining Faust app
# app = faust.App('temperature-stream', broker='kafka://localhost:29092')
#
# # Defining the input and output Kafka topics
# input_topic = app.topic('InputData', value_type=bytes)
# output_topic = app.topic('Output', value_type=bytes)
# outliers_topic = app.topic('Outliers', value_type=bytes)

# %% [markdown]
# Next, we define a stream processor using the @agent decorator to consume data from the Kafka 'InputData' topic. The processor will detect outliers and compute the mean hourly air temperature for each station and each date. Temperatures below -60°C and above 60°C are considered outliers. If an outlier is detected, it is excluded from the calculation of the mean hourly temperature. Outlier data is written to the 'Outliers' topic, while the mean hourly air temperature for each station is written to the 'Output' topic. The code section for this part is shown below.

# %% [markdown]
# ```python
#
# # Function for detecting outliers
# def detect_outliers(record):
#     if record.AIR_TEMPERATURE < -60 or record.AIR_TEMPERATURE > 60:
#         outlier = OutlierRecord(
#             station=record.WBANNO,
#             lst_date=f"{str(record.LST_DATE)[:4]}-{str(record.LST_DATE)[4:6]}-{str(record.LST_DATE)[6:]}",
#             lst_time=f"{str(record.LST_TIME)[:2]}:{str(record.LST_TIME)[2:]}",
#             temp=record.AIR_TEMPERATURE,
#             source_file = record.source_file
#         )
#         return outlier
#     return None
#
# # Function for computing mean temperature
# def compute_mean_temp(station, date, hour, temps):
#     mean_temp = sum(temps) / len(temps)
#     hourly_temp = HourlyTemperature(
#         station=station,
#         lst_date=f"{str(date)[:4]}-{str(date)[4:6]}-{str(date)[6:]}",
#         lst_hour=hour,
#         mean_temp=mean_temp
#     )
#     return hourly_temp
#
#
# @app.agent(input_topic)
# async def process_temperature(records):
#     current_date = None
#     current_hour = None
#     current_station = None
#     temps = []
#     async for record in records:
#         record = InputRecord(**record)
#
#         # Check if record is an outlier and skip the rest of the loop if it is
#         outlier = detect_outliers(record)
#         if outlier:
#             await outliers_topic.send(value=outlier)
#             continue
#
#         station = record.WBANNO
#         date = record.LST_DATE
#         lst_time = f"{record.LST_TIME:04d}"
#         hour = lst_time[:2]
#         temp = record.AIR_TEMPERATURE
#
#         # Check if the hour or station has changed and compute hourly mean temperature
#         if (current_station is not None and (hour != current_hour or date != current_date)):
#             hourly_temp = compute_mean_temp(current_station, current_date, current_hour, temps)
#             await output_topic.send(value=hourly_temp)
#             temps = []
#
#         # Update current hour, date and station
#         current_hour = hour
#         current_station = station
#         current_date =  date
#
#         # Append the temperature for current record to the list
#         temps.append(temp)
#
#     hourly_temp = compute_mean_temp(current_station, current_date, current_hour, temps)
#     await output_topic.send(value=hourly_temp)

# %% [markdown]
# ## Defining Kafka Consumer

# %% [markdown]
# Next we define a Kafka consumer function, 'run_consumer', for reading the messages from a specified Kafka topic. The consumer is configured to start reading from the earliest available message. Inside the main loop, the consumer polls for messages and can output the messages to the console (if 'print_output' argument is set to True) or store them in a queue (if 'queue_storage' is specified). Additionally, the loop can be interrupted by an external stop flag or automatically if no messages are received for a certain number of consecutive polls in the 'Output' topic.

# %%
# Consumer function
def run_consumer(topic_name, print_output=True, queue_storage=None, stop_flag=None):
    
    consumer = kafka.Consumer({
        'bootstrap.servers': 'localhost:29092',
        'client.id': socket.gethostname(),
        'group.id': 'test_group',
        'auto.offset.reset': 'earliest'})
    consumer.subscribe([topic_name])
    logging.info(f"Consumer subscribed to topic: {topic_name}")

    if print_output==True:
        print(f"Received messages from {topic_name}:")

    try:
        count = 0
        while True:
            # Break out of the loop if stop_flag is set
            if stop_flag and stop_flag.is_set():
                break
            msg = consumer.poll(timeout=1.0)
            if msg is None:
                # Increment count if no message received
                count += 1
                # Break out of the loop if no message is received for 10 consecutive polls in Output topic
                if (topic_name == 'Output' or topic_name == 'MaxTemp') and count > 10:
                    logging.info('No message received.')
                    break
                continue
            if msg.error():
                if msg.error().code() == KafkaError._PARTITION_EOF:
                    continue
                else:
                    logging.error('Error occurred: {}'.format(msg.error()))
                    print(msg.error())
                    break
            else:
                data = json.loads(msg.value().decode('utf-8'))
                if print_output==True:
                    print(f"{data}")
                if queue_storage:
                    queue_storage.put(data)
                count = 0

    except KeyboardInterrupt:
        pass
    finally:
        consumer.close()
        logging.info(f"Consumer for {topic_name} closed")

# %% [markdown]
# ## Running Producer and Consumer

# %% [markdown]
# To simulate real-time data streaming and processing, we need to simultaneously run the 'faust_app.py' script, the Producer, and the Consumer. We leverage Python's threading library to run the Producer and Consumer threads concurrently within a Jupyter Notebook, while the faust_app.py script is executed from the terminal. Since there are two Consumers that write to different topics, Output and Outliers, we will configure the Consumer that writes mean hourly temperatures to the Output topic to print the data. The Consumer that writes to the Outliers topic will be configured to store the data in a queue. This approach ensures that the outputs from these Consumers do not get mixed.

# %%
# Defining the queue for storing outliers
outliers_queue = Queue()

# Define stop flag
stop_flag = threading.Event()

# Creating threads for one producer and 2 consumers
producer_thread = threading.Thread(target=run_producer)
consumer_thread_1 = threading.Thread(target=run_consumer, args=('Output', True, None, None))
consumer_thread_2 = threading.Thread(target=run_consumer, args=('Outliers', False, outliers_queue, stop_flag))

# Run producer and consumer threads in parallel
producer_thread.start()
consumer_thread_1.start()
consumer_thread_2.start()

producer_thread.join()
consumer_thread_1.join()

# Set the stop flag to stop the second consumer thread when first consumer flags finishes
stop_flag.set()

consumer_thread_2.join()
# Out:
# INFO:root:Consumer subscribed to topic: Output
# INFO:root:Consumer subscribed to topic: Outliers
# Received messages from Output:
# {'station': 23907, 'lst_date': '2020-12-31', 'lst_hour': '18', 'mean_temp': 0.7181818181818181, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2020-12-31', 'lst_hour': '19', 'mean_temp': 0.5333333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2020-12-31', 'lst_hour': '20', 'mean_temp': 0.3916666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2020-12-31', 'lst_hour': '21', 'mean_temp': 0.46666666666666673, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2020-12-31', 'lst_hour': '22', 'mean_temp': 0.43333333333333335, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2020-12-31', 'lst_hour': '23', 'mean_temp': 0.29999999999999993, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '00', 'mean_temp': 0.27499999999999997, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '01', 'mean_temp': 0.35000000000000003, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '02', 'mean_temp': 0.4666666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '03', 'mean_temp': 0.7000000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '04', 'mean_temp': 0.8333333333333335, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '05', 'mean_temp': 1.0999999999999999, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '06', 'mean_temp': 1.5250000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '07', 'mean_temp': 1.6083333333333332, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '08', 'mean_temp': 2.1083333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '09', 'mean_temp': 3.0666666666666664, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '10', 'mean_temp': 3.8249999999999997, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '11', 'mean_temp': 5.208333333333332, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '12', 'mean_temp': 6.966666666666668, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '13', 'mean_temp': 7.116666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '14', 'mean_temp': 7.683333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '15', 'mean_temp': 8.858333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '16', 'mean_temp': 8.6, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '17', 'mean_temp': 6.924999999999998, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '18', 'mean_temp': 5.075, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '19', 'mean_temp': 3.891666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '20', 'mean_temp': 3.1166666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '21', 'mean_temp': 2.9499999999999997, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '22', 'mean_temp': 2.9416666666666664, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '23', 'mean_temp': 2.6666666666666665, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '00', 'mean_temp': 1.9416666666666664, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '01', 'mean_temp': 1.8833333333333335, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '02', 'mean_temp': 1.9833333333333336, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '03', 'mean_temp': 1.8499999999999996, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '04', 'mean_temp': 1.5666666666666664, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '05', 'mean_temp': 0.6999999999999998, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '06', 'mean_temp': 0.47500000000000003, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '07', 'mean_temp': 0.17500000000000002, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '08', 'mean_temp': 1.6833333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '09', 'mean_temp': 5.883333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '10', 'mean_temp': 8.375, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '11', 'mean_temp': 10.641666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '12', 'mean_temp': 12.533333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '13', 'mean_temp': 13.933333333333332, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '14', 'mean_temp': 14.975, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '15', 'mean_temp': 15.283333333333331, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '16', 'mean_temp': 14.975000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '17', 'mean_temp': 13.066666666666668, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '18', 'mean_temp': 11.041666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '19', 'mean_temp': 10.441666666666665, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '20', 'mean_temp': 9.825000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '21', 'mean_temp': 8.575000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '22', 'mean_temp': 7.841666666666668, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-02', 'lst_hour': '23', 'mean_temp': 6.683333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '00', 'mean_temp': 5.458333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '01', 'mean_temp': 5.891666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '02', 'mean_temp': 5.983333333333332, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '03', 'mean_temp': 5.916666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '04', 'mean_temp': 6.508333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '05', 'mean_temp': 5.5, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '06', 'mean_temp': 5.599999999999999, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '07', 'mean_temp': 6.425000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '08', 'mean_temp': 8.108333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '09', 'mean_temp': 10.75, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '10', 'mean_temp': 13.775, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '11', 'mean_temp': 16.708333333333336, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '12', 'mean_temp': 18.425, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '13', 'mean_temp': 19.474999999999998, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '14', 'mean_temp': 20.358333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '15', 'mean_temp': 20.39166666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '16', 'mean_temp': 20.058333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '17', 'mean_temp': 18.14166666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '18', 'mean_temp': 15.541666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '19', 'mean_temp': 14.191666666666665, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '20', 'mean_temp': 13.141666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '21', 'mean_temp': 11.799999999999999, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '22', 'mean_temp': 11.691666666666668, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-03', 'lst_hour': '23', 'mean_temp': 11.5, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '00', 'mean_temp': 10.233333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '01', 'mean_temp': 9.5, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '02', 'mean_temp': 9.174999999999999, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '03', 'mean_temp': 9.299999999999999, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '04', 'mean_temp': 9.325, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '05', 'mean_temp': 8.525, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '06', 'mean_temp': 8.616666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '07', 'mean_temp': 8.875, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '08', 'mean_temp': 10.649999999999999, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '09', 'mean_temp': 13.299999999999999, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '10', 'mean_temp': 16.44166666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '11', 'mean_temp': 18.508333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '12', 'mean_temp': 20.29166666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '13', 'mean_temp': 21.283333333333335, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '14', 'mean_temp': 22.166666666666668, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '15', 'mean_temp': 21.541666666666668, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '16', 'mean_temp': 20.541666666666668, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '17', 'mean_temp': 17.516666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '18', 'mean_temp': 14.475000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '19', 'mean_temp': 13.249999999999998, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '20', 'mean_temp': 12.316666666666665, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '21', 'mean_temp': 11.950000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '22', 'mean_temp': 11.441666666666668, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-04', 'lst_hour': '23', 'mean_temp': 10.699999999999998, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '00', 'mean_temp': 10.408333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '01', 'mean_temp': 9.866666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '02', 'mean_temp': 9.616666666666665, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '03', 'mean_temp': 9.408333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '04', 'mean_temp': 9.208333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '05', 'mean_temp': 8.916666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '06', 'mean_temp': 8.175, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '07', 'mean_temp': 7.816666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '08', 'mean_temp': 9.258333333333335, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '09', 'mean_temp': 11.991666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '10', 'mean_temp': 14.450000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '11', 'mean_temp': 16.99166666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '12', 'mean_temp': 18.366666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '13', 'mean_temp': 19.025000000000002, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '14', 'mean_temp': 19.50833333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '15', 'mean_temp': 19.474999999999998, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '16', 'mean_temp': 18.474999999999998, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '17', 'mean_temp': 16.566666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '18', 'mean_temp': 15.700000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '19', 'mean_temp': 15.274999999999999, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '20', 'mean_temp': 15.049999999999999, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '21', 'mean_temp': 15.19166666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '22', 'mean_temp': 15.266666666666664, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-05', 'lst_hour': '23', 'mean_temp': 15.124999999999998, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '00', 'mean_temp': 14.933333333333337, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '01', 'mean_temp': 14.875000000000005, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '02', 'mean_temp': 14.749999999999998, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '03', 'mean_temp': 14.599999999999996, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '04', 'mean_temp': 14.733333333333336, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '05', 'mean_temp': 14.841666666666669, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '06', 'mean_temp': 14.891666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '07', 'mean_temp': 15.0, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '08', 'mean_temp': 15.150000000000004, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '09', 'mean_temp': 15.691666666666665, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '10', 'mean_temp': 16.125000000000004, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '11', 'mean_temp': 12.666666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '12', 'mean_temp': 13.80833333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '13', 'mean_temp': 15.491666666666665, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '14', 'mean_temp': 15.950000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '15', 'mean_temp': 15.458333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '16', 'mean_temp': 14.966666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '17', 'mean_temp': 13.541666666666664, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '18', 'mean_temp': 11.983333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '19', 'mean_temp': 10.983333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '20', 'mean_temp': 9.941666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '21', 'mean_temp': 9.875, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '22', 'mean_temp': 8.583333333333332, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_hour': '23', 'mean_temp': 7.683333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '00', 'mean_temp': 7.141666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '01', 'mean_temp': 6.408333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '02', 'mean_temp': 6.366666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '03', 'mean_temp': 6.416666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '04', 'mean_temp': 6.308333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '05', 'mean_temp': 6.058333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '06', 'mean_temp': 5.7749999999999995, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '07', 'mean_temp': 4.616666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '08', 'mean_temp': 4.866666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '09', 'mean_temp': 6.875, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '10', 'mean_temp': 8.725, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '11', 'mean_temp': 10.424999999999999, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '12', 'mean_temp': 12.008333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '13', 'mean_temp': 13.074999999999998, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '14', 'mean_temp': 14.016666666666671, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '15', 'mean_temp': 14.458333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '16', 'mean_temp': 13.79166666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '17', 'mean_temp': 11.783333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '18', 'mean_temp': 9.31666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '19', 'mean_temp': 8.208333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '20', 'mean_temp': 7.591666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '21', 'mean_temp': 6.675, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '22', 'mean_temp': 5.6499999999999995, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-07', 'lst_hour': '23', 'mean_temp': 4.1, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '00', 'mean_temp': 3.6250000000000004, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '01', 'mean_temp': 2.9416666666666664, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '02', 'mean_temp': 2.5750000000000006, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '03', 'mean_temp': 2.625, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '04', 'mean_temp': 2.158333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '05', 'mean_temp': 1.491666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '06', 'mean_temp': 0.9249999999999999, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '07', 'mean_temp': 0.5416666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '08', 'mean_temp': 2.1750000000000003, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '09', 'mean_temp': 4.258333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '10', 'mean_temp': 5.233333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '11', 'mean_temp': 6.483333333333332, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '12', 'mean_temp': 7.433333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '13', 'mean_temp': 8.341666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '14', 'mean_temp': 8.958333333333332, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '15', 'mean_temp': 9.133333333333335, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '16', 'mean_temp': 8.533333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '17', 'mean_temp': 6.908333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '18', 'mean_temp': 4.466666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '19', 'mean_temp': 3.8666666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '20', 'mean_temp': 2.991666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '21', 'mean_temp': 2.8249999999999997, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '22', 'mean_temp': 2.691666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-08', 'lst_hour': '23', 'mean_temp': 2.475, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '00', 'mean_temp': 2.55, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '01', 'mean_temp': 2.033333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '02', 'mean_temp': 1.4000000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '03', 'mean_temp': 0.8249999999999998, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '04', 'mean_temp': 0.43333333333333335, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '05', 'mean_temp': 0.2666666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '06', 'mean_temp': -0.19999999999999998, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '07', 'mean_temp': -0.6583333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '08', 'mean_temp': 0.8000000000000002, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '09', 'mean_temp': 3.15, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '10', 'mean_temp': 5.45, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '11', 'mean_temp': 7.374999999999999, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '12', 'mean_temp': 8.408333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '13', 'mean_temp': 9.4, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '14', 'mean_temp': 9.766666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '15', 'mean_temp': 9.366666666666665, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '16', 'mean_temp': 8.566666666666668, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '17', 'mean_temp': 7.533333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '18', 'mean_temp': 6.8166666666666655, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '19', 'mean_temp': 6.316666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '20', 'mean_temp': 6.016666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '21', 'mean_temp': 5.791666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '22', 'mean_temp': 5.608333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-09', 'lst_hour': '23', 'mean_temp': 5.491666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '00', 'mean_temp': 5.366666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '01', 'mean_temp': 5.116666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '02', 'mean_temp': 4.116666666666665, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '03', 'mean_temp': 3.616666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '04', 'mean_temp': 3.3833333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '05', 'mean_temp': 2.858333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '06', 'mean_temp': 1.9416666666666664, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '07', 'mean_temp': 1.3833333333333335, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '08', 'mean_temp': 0.8500000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '09', 'mean_temp': 0.5333333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '10', 'mean_temp': 0.16666666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '11', 'mean_temp': 0.03333333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '12', 'mean_temp': -0.09166666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '13', 'mean_temp': -0.075, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '14', 'mean_temp': 0.049999999999999996, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '15', 'mean_temp': 0.10833333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '16', 'mean_temp': 0.16666666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '17', 'mean_temp': 0.19999999999999998, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '18', 'mean_temp': 0.19999999999999998, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '19', 'mean_temp': 0.11666666666666668, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '20', 'mean_temp': 0.09999999999999999, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '21', 'mean_temp': 0.10833333333333332, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '22', 'mean_temp': 0.19999999999999998, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-10', 'lst_hour': '23', 'mean_temp': 0.18333333333333332, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '00', 'mean_temp': 0.09999999999999999, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '01', 'mean_temp': 0.008333333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '02', 'mean_temp': -0.03333333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '03', 'mean_temp': -0.041666666666666664, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '04', 'mean_temp': -0.025000000000000005, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '05', 'mean_temp': 0.11666666666666665, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '06', 'mean_temp': -0.10833333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '07', 'mean_temp': -0.275, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '08', 'mean_temp': 0.17500000000000002, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '09', 'mean_temp': 0.625, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '10', 'mean_temp': 1.758333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '11', 'mean_temp': 2.941666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '12', 'mean_temp': 4.074999999999999, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '13', 'mean_temp': 5.025000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '14', 'mean_temp': 5.366666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '15', 'mean_temp': 5.8999999999999995, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '16', 'mean_temp': 5.641666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '17', 'mean_temp': 4.325, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '18', 'mean_temp': 2.441666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '19', 'mean_temp': 1.6500000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '20', 'mean_temp': 1.2333333333333336, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '21', 'mean_temp': 0.38333333333333336, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '22', 'mean_temp': 2.3129646346357427e-18, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-11', 'lst_hour': '23', 'mean_temp': -0.06666666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '00', 'mean_temp': -0.27499999999999997, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '01', 'mean_temp': -0.35000000000000003, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '02', 'mean_temp': -0.40833333333333327, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '03', 'mean_temp': -0.26666666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '04', 'mean_temp': -0.075, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '05', 'mean_temp': -0.16666666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '06', 'mean_temp': -0.5833333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '07', 'mean_temp': -0.6666666666666669, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '08', 'mean_temp': 1.2083333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '09', 'mean_temp': 3.133333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '10', 'mean_temp': 5.4333333333333345, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '11', 'mean_temp': 7.175000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '12', 'mean_temp': 8.35, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '13', 'mean_temp': 8.958333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '14', 'mean_temp': 9.566666666666668, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '15', 'mean_temp': 9.85, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '16', 'mean_temp': 8.925, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '17', 'mean_temp': 8.291666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '18', 'mean_temp': 6.933333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '19', 'mean_temp': 5.308333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '20', 'mean_temp': 4.175, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '21', 'mean_temp': 3.4583333333333335, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '22', 'mean_temp': 2.841666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-12', 'lst_hour': '23', 'mean_temp': 1.9833333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '00', 'mean_temp': 1.875, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '01', 'mean_temp': 2.4416666666666664, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '02', 'mean_temp': 1.8666666666666665, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '03', 'mean_temp': 2.091666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '04', 'mean_temp': 1.9666666666666668, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '05', 'mean_temp': 1.6416666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '06', 'mean_temp': 1.758333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '07', 'mean_temp': 1.3083333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '08', 'mean_temp': 2.6666666666666665, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '09', 'mean_temp': 5.241666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '10', 'mean_temp': 8.341666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '11', 'mean_temp': 11.0, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '12', 'mean_temp': 13.35, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '13', 'mean_temp': 15.15, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '14', 'mean_temp': 16.383333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '15', 'mean_temp': 17.3, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '16', 'mean_temp': 17.400000000000002, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '17', 'mean_temp': 15.908333333333331, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '18', 'mean_temp': 13.358333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '19', 'mean_temp': 11.79166666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '20', 'mean_temp': 10.616666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '21', 'mean_temp': 9.508333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '22', 'mean_temp': 9.183333333333335, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-13', 'lst_hour': '23', 'mean_temp': 8.891666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-14', 'lst_hour': '00', 'mean_temp': 8.658333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-14', 'lst_hour': '01', 'mean_temp': 8.191666666666665, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-14', 'lst_hour': '02', 'mean_temp': 8.858333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-14', 'lst_hour': '03', 'mean_temp': 9.083333333333332, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-14', 'lst_hour': '04', 'mean_temp': 8.691666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-14', 'lst_hour': '05', 'mean_temp': 8.808333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-14', 'lst_hour': '06', 'mean_temp': 8.4, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-14', 'lst_hour': '07', 'mean_temp': 7.791666666666665, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-14', 'lst_hour': '08', 'mean_temp': 10.15, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-14', 'lst_hour': '09', 'mean_temp': 12.541666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-14', 'lst_hour': '10', 'mean_temp': 15.116666666666665, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-14', 'lst_hour': '11', 'mean_temp': 16.033333333333335, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-14', 'lst_hour': '12', 'mean_temp': 16.71666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 23907, 'lst_date': '2021-01-14', 'lst_hour': '13', 'mean_temp': 17.233333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# ...
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '02', 'mean_temp': -5.825, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '03', 'mean_temp': -5.808333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '04', 'mean_temp': -5.916666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '05', 'mean_temp': -7.441666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '06', 'mean_temp': -8.45, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '07', 'mean_temp': -8.800000000000002, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '08', 'mean_temp': -8.975000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '09', 'mean_temp': -9.183333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '10', 'mean_temp': -8.691666666666668, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '11', 'mean_temp': -8.075, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '12', 'mean_temp': -8.200000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '13', 'mean_temp': -8.566666666666668, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '14', 'mean_temp': -9.341666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '15', 'mean_temp': -9.958333333333332, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '16', 'mean_temp': -10.391666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '17', 'mean_temp': -10.883333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '18', 'mean_temp': -12.375, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '19', 'mean_temp': -12.700000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '20', 'mean_temp': -12.641666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '21', 'mean_temp': -12.466666666666669, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '22', 'mean_temp': -12.308333333333332, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-27', 'lst_hour': '23', 'mean_temp': -11.850000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '00', 'mean_temp': -11.283333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '01', 'mean_temp': -11.149999999999999, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '02', 'mean_temp': -11.183333333333332, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '03', 'mean_temp': -11.225000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '04', 'mean_temp': -11.508333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '05', 'mean_temp': -12.200000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '06', 'mean_temp': -13.308333333333337, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '07', 'mean_temp': -14.191666666666668, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '08', 'mean_temp': -13.341666666666663, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '09', 'mean_temp': -12.183333333333335, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '10', 'mean_temp': -11.791666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '11', 'mean_temp': -11.008333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '12', 'mean_temp': -10.758333333333335, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '13', 'mean_temp': -10.208333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '14', 'mean_temp': -9.833333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '15', 'mean_temp': -12.383333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '16', 'mean_temp': -16.533333333333335, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '17', 'mean_temp': -17.666666666666664, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '18', 'mean_temp': -17.816666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '19', 'mean_temp': -16.3, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '20', 'mean_temp': -15.075000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '21', 'mean_temp': -15.425000000000002, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '22', 'mean_temp': -18.375, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-28', 'lst_hour': '23', 'mean_temp': -20.049999999999997, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '00', 'mean_temp': -19.883333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '01', 'mean_temp': -17.808333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '02', 'mean_temp': -14.300000000000002, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '03', 'mean_temp': -13.916666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '04', 'mean_temp': -13.30833333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '05', 'mean_temp': -12.83333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '06', 'mean_temp': -12.508333333333335, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '07', 'mean_temp': -12.558333333333332, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '08', 'mean_temp': -12.783333333333331, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '09', 'mean_temp': -12.058333333333335, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '10', 'mean_temp': -11.108333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '11', 'mean_temp': -10.774999999999999, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '12', 'mean_temp': -10.383333333333335, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '13', 'mean_temp': -10.074999999999998, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '14', 'mean_temp': -10.15, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '15', 'mean_temp': -10.283333333333331, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '16', 'mean_temp': -10.458333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '17', 'mean_temp': -11.358333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '18', 'mean_temp': -12.766666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '19', 'mean_temp': -13.266666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '20', 'mean_temp': -12.575000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '21', 'mean_temp': -12.933333333333332, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '22', 'mean_temp': -12.891666666666671, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-29', 'lst_hour': '23', 'mean_temp': -12.649999999999999, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '00', 'mean_temp': -12.475000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '01', 'mean_temp': -11.791666666666666, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '02', 'mean_temp': -11.375, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '03', 'mean_temp': -11.400000000000004, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '04', 'mean_temp': -11.366666666666669, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '05', 'mean_temp': -11.324999999999998, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '06', 'mean_temp': -11.258333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '07', 'mean_temp': -11.016666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '08', 'mean_temp': -10.133333333333335, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '09', 'mean_temp': -9.091666666666669, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '10', 'mean_temp': -8.75, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '11', 'mean_temp': -8.725, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '12', 'mean_temp': -9.933333333333335, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '13', 'mean_temp': -9.708333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '14', 'mean_temp': -9.308333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '15', 'mean_temp': -9.441666666666668, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '16', 'mean_temp': -9.808333333333335, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '17', 'mean_temp': -9.958333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '18', 'mean_temp': -10.033333333333331, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '19', 'mean_temp': -10.049999999999999, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '20', 'mean_temp': -10.208333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '21', 'mean_temp': -10.408333333333335, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '22', 'mean_temp': -10.533333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-30', 'lst_hour': '23', 'mean_temp': -10.85, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-31', 'lst_hour': '00', 'mean_temp': -11.358333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-31', 'lst_hour': '01', 'mean_temp': -11.283333333333331, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-31', 'lst_hour': '02', 'mean_temp': -11.333333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-31', 'lst_hour': '03', 'mean_temp': -12.225, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-31', 'lst_hour': '04', 'mean_temp': -12.216666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-31', 'lst_hour': '05', 'mean_temp': -12.375, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-31', 'lst_hour': '06', 'mean_temp': -13.300000000000002, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-31', 'lst_hour': '07', 'mean_temp': -14.274999999999999, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-31', 'lst_hour': '08', 'mean_temp': -15.908333333333333, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-31', 'lst_hour': '09', 'mean_temp': -12.933333333333337, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-31', 'lst_hour': '10', 'mean_temp': -10.733333333333334, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-31', 'lst_hour': '11', 'mean_temp': -9.975, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-31', 'lst_hour': '12', 'mean_temp': -10.241666666666667, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-31', 'lst_hour': '13', 'mean_temp': -10.683333333333332, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-31', 'lst_hour': '14', 'mean_temp': -12.049999999999999, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# {'station': 4136, 'lst_date': '2021-12-31', 'lst_hour': '15', 'mean_temp': -11.225000000000001, '__faust': {'ns': 'faust_app.HourlyTemperature'}}
# INFO:root:No message received.
# INFO:root:Consumer for Output closed
# INFO:root:Consumer for Outliers closed

# %%
# Print collected outliers from Outliers topic
print("Outliers Data:")
while not outliers_queue.empty():
    outlier = outliers_queue.get()
    print(outlier)
# Out:
# Outliers Data:
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_time': '11:25', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_time': '11:30', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-01-06', 'lst_time': '11:35', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-02-27', 'lst_time': '14:10', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-03-03', 'lst_time': '12:20', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-03-03', 'lst_time': '12:25', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-07-07', 'lst_time': '82:0', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-07-20', 'lst_time': '83:0', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-07-26', 'lst_time': '13:35', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-09-05', 'lst_time': '13:10', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-09-23', 'lst_time': '70:5', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-10-01', 'lst_time': '95:0', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-10-01', 'lst_time': '95:5', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-10-15', 'lst_time': '83:0', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-10-15', 'lst_time': '83:5', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-11-02', 'lst_time': '10:00', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-11-14', 'lst_time': '12:35', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-11-25', 'lst_time': '54:5', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-11-25', 'lst_time': '55:0', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-11-25', 'lst_time': '55:5', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-12-08', 'lst_time': '12:25', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-12-14', 'lst_time': '11:30', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-12-14', 'lst_time': '11:35', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-12-14', 'lst_time': '11:40', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-12-14', 'lst_time': '11:45', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-12-14', 'lst_time': '11:50', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-12-14', 'lst_time': '11:55', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-12-14', 'lst_time': '12:00', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-12-14', 'lst_time': '12:05', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-12-14', 'lst_time': '12:10', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-12-14', 'lst_time': '12:15', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-12-18', 'lst_time': '63:0', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-12-18', 'lst_time': '63:5', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-12-26', 'lst_time': '10:50', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-12-26', 'lst_time': '10:55', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-12-26', 'lst_time': '11:00', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-12-26', 'lst_time': '11:05', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-12-26', 'lst_time': '11:10', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 23907, 'lst_date': '2021-12-26', 'lst_time': '11:15', 'temp': -9999.0, 'source_file': 'Austin_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 3072, 'lst_date': '2021-12-06', 'lst_time': '31:0', 'temp': -9999.0, 'source_file': 'Bronte_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '90:5', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '91:0', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '91:5', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '92:0', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '92:5', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '93:0', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '93:5', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '94:0', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '94:5', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '95:0', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '95:5', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '10:00', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '10:05', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '10:10', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '10:15', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '10:20', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '10:25', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '10:30', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '10:35', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '10:40', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '10:45', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '10:50', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '10:55', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '11:00', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '11:05', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '11:10', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '11:15', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '11:20', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '11:25', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '11:30', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '11:35', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '11:40', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '11:45', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '11:50', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '11:55', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '12:00', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '12:05', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '12:10', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '12:15', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '12:20', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '12:25', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '12:30', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '12:35', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '12:40', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '12:45', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '12:50', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '12:55', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-12', 'lst_time': '13:00', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}
# {'station': 4136, 'lst_date': '2021-11-22', 'lst_time': '95:5', 'temp': -9999.0, 'source_file': 'Spokane_data.txt', '__faust': {'ns': 'faust_app.OutlierRecord'}}

# %% [markdown]
# ## Parallel Streaming and Data Processing

# %% [markdown]
# Next, we want to determine the station with the highest air temperature each hour. For this task we need to use parallel streaming and data processing techniques. We begin by creating a Kafka topic 'Partitioned' with three partitions. Each producer is responsible for handling one text file (data for one station) and for sending its data to a unique partition within the same topic. Utilizing Faust, we process the incoming data to identify the station recording the maximum air temperature every hour. The results are written back to a separate MaxTemp topic. For demonstration purposes, we focus on data from a single date: January 1, 2021.

# %%
# Defining producer configuration
producer = kafka.Producer({'bootstrap.servers': "localhost:29092",
                  'client.id': socket.gethostname()})


def run_producer_for_partition(file_path, partition):
    if os.path.isfile(file_path):
        df = pd.read_csv(file_path, delimiter=r'\s+', names=columns)
        # Filter for only one date
        df = df[df['LST_DATE'] == 20210101]                         
        for _, row in df.iterrows():
            data = row.to_dict()
            data['source_file'] = file_path  
            producer.produce('Partitioned', key=None, value=json.dumps(data), partition=partition, callback=error_report)
            producer.flush()
            
    logging.info(f"Messages from {file_path} delivered to Partitioned Topic at partition {partition}!")


def run_producers_in_parallel():
    threads = []
    for i, filename in enumerate(filenames):
        file_path = os.path.join(data_path, filename)
        thread = threading.Thread(target=run_producer_for_partition, args=(file_path, i))
        threads.append(thread)

    for thread in threads:
        thread.start()

    for thread in threads:
        thread.join()

# %% [markdown]
# The following code section is from 'faust_app.py'. Given that the data was collected every 5 minutes, we gather 12 records from each partition (each station) and determine the maximum value among them. This maximum value represents the highest air temperature for the current hour. We then write this value to the 'MaxTemp' topic. This process is repeated for each hour to continuously identify the station with the maximum air temperature

# %% [markdown]
# ```python
# # Defining the input and output Kafka topics
# partitioned_topic = app.topic('Partitioned', value_type=bytes)
# max_temp_topic = app.topic('MaxTemp', value_type=bytes)
#
# # Defining Faust Schema for the output
# class MaxTemperatureRecord(faust.Record):
#     max_temp: float
#     station: str
#     lst_date: str
#     lst_hour: str
#     source_file: str
#
# # Dictionary to hold the current records for comparison
# current_records = {0: [], 1: [],2: []}
#
# @app.agent(partitioned_topic)
# async def max_temp_process(stream):
#     async for event in stream.events():
#         record = InputRecord(**event.value)
#         partition = event.message.partition
#
#         current_records[partition].append(record)
#
#         # Check if we have 12 records for each partition
#         if all(len(records) >= 12 for records in current_records.values()):
#             combined_records = [rec for recs in current_records.values() for rec in recs[:12]]
#
#             # Find the record with the maximum temperature
#             max_record = max(combined_records, key=lambda x: x.AIR_TEMPERATURE)
#
#             # Create the max temperature record
#             date = max_record.LST_DATE
#             lst_time = f"{record.LST_TIME:04d}"
#             max_temp_record = MaxTemperatureRecord(
#                 max_temp=max_record.AIR_TEMPERATURE,
#                 station=max_record.WBANNO,
#                 lst_date=f"{str(date)[:4]}-{str(date)[4:6]}-{str(date)[6:]}",
#                 lst_hour=lst_time[:2],
#                 source_file=max_record.source_file
#             )
#             await max_temp_topic.send(value=max_temp_record)
#
#
#             # Reset the current_records dictionary
#             for partition in current_records.keys():
#                 current_records[partition] = current_records[partition][12:]

# %% [markdown]
# Finally, we simultaneously run the 'faust_app.py' in terminal along with the producer and consumer threads. This setup ensures that data is continuously produced, processed and consumed.

# %%
# Creating threads for one producer and consumer
parallel_producer_threads = threading.Thread(target=run_producers_in_parallel)
consumer_thread = threading.Thread(target=run_consumer, args = ('MaxTemp', True, None))

# Run producer and consumer threads in parallel
parallel_producer_threads.start()
consumer_thread.start()

parallel_producer_threads.join()
consumer_thread.join()
# Out:
# INFO:root:Consumer subscribed to topic: MaxTemp
# Received messages from MaxTemp:
# {'max_temp': 2.4, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '00', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.1, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '01', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.2, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '02', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.2, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '03', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.0, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '04', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.2, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '05', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.3, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '06', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.7, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '07', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.8, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '08', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 3.3, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '09', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 4.2, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '10', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 6.3, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '11', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 7.7, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '12', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 7.7, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '13', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 8.5, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '14', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 9.2, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '15', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 8.9, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '16', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 7.9, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '17', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 5.7, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '18', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 4.8, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '19', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 3.8, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '20', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 3.9, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '21', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 3.5, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '22', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 3.3, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '23', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.4, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '00', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.1, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '01', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.2, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '02', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.2, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '03', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.0, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '04', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.2, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '05', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.3, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '06', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.7, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '07', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.8, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '08', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 3.3, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '09', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 4.2, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '10', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 6.3, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '11', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 7.7, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '12', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 7.7, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '13', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 8.5, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '14', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 9.2, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '15', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 8.9, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '16', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 7.9, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '17', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 5.7, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '18', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 4.8, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '19', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 3.8, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '20', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 3.9, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '21', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 3.5, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '22', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 3.3, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '23', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.4, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '00', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.1, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '01', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.2, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '02', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.2, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '03', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.0, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '04', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.2, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '05', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.3, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '06', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.7, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '07', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 2.8, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '08', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 3.3, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '09', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 4.2, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '10', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 6.3, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '11', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 7.7, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '12', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 7.7, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '13', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 8.5, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '14', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 9.2, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '15', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 8.9, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '16', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 7.9, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '17', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 5.7, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '18', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 4.8, 'station': 23907, 'lst_date': '2021-01-01', 'lst_hour': '19', 'source_file': './data/Austin_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 3.8, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '20', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 3.9, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '21', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# {'max_temp': 3.5, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '22', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# INFO:root:Messages from ./data/Spokane_data.txt delivered to Partitioned Topic at partition 2!
# INFO:root:Messages from ./data/Bronte_data.txt delivered to Partitioned Topic at partition 1!
# INFO:root:Messages from ./data/Austin_data.txt delivered to Partitioned Topic at partition 0!
# {'max_temp': 3.3, 'station': 4136, 'lst_date': '2021-01-01', 'lst_hour': '23', 'source_file': './data/Spokane_data.txt', '__faust': {'ns': 'faust_app.MaxTemperatureRecord'}}
# INFO:root:No message received.
# INFO:root:Consumer for MaxTemp closed
